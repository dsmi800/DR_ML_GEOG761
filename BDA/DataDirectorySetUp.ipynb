# %% [markdown]
# # 2. Data Directory Setup #

# %% [markdown]
# ## VERY IMPORTANT REMINDER! ##
# If you have not done this already:
# 1. Create two folders in your directory - call one <code>Pre-v2</code> and call the other <code>Post-v2</code>
# 2. Move all folders containing pre-event imagery (downloaded in the <code>DownloadMoroccoData.ipynb</code> file) into the <code>Pre-v2</code> folder and all the folders containing post-event imagery into the <code>Post-v2</code> folder.

# %% [markdown]
# ### Rename pre-event images and move all images into a new folder called <code>Pre-event-v2</code>

# %%
# Code reference: This work used ChatGPT-3.5 to generate the initial functions and report outline. This was done on 20/09/2023
# with the following prompts: "Generate code to move images in subfolders into a new folder and rename each image to be unique"

# Import required packages
import os
import shutil

# Specify the path to your Pre-v2 folder (main folder) that contains the pre-imagery subfolders
main_folder = 'Pre-v3'
# Specify the destination folder for renamed images to be moved to
dest_folder = 'Pre-event-v3'

# Check if the destination folder (Pre-event-v2) already exists and if it does not, then create the folder
if not os.path.exists(dest_folder):
    os.mkdir(dest_folder)
    print(f"Folder '{dest_folder}' created successfully.")
else:
    print(f"Folder '{dest_folder}' already exists.")

# List all subfolders in the main Pre-v2 folder
subfolders = [f.path for f in os.scandir(main_folder) if f.is_dir()]
print(subfolders)

# Iterate through the subfolders
for subfolder in subfolders:
    # List all files in the subfolder
    subfolder_files = os.listdir(subfolder)
    print("FOLDER",subfolder)
    
    # Iterate through the files in the subfolder
    for file in subfolder_files:
        print(file)
        
        # Get the full path to the file in the subfolder
        file_path = os.path.join(subfolder, file)

        # Create a new file name with the subfolder name as a prefix
        new_file_name = f"{os.path.basename(subfolder)}_{file}"
        
        # Get the full path to the new file in the subfolder
        new_file_path = os.path.join(subfolder, new_file_name)

        # Rename the file in the subfolder
        os.rename(file_path, new_file_path)
        
print("Images have been renamed.")
# Out:
# Folder 'Pre-event-v3' created successfully.
# ['Pre-v3/10400100405FEB00', 'Pre-v3/10400100797DAC00', 'Pre-v3/1040010045AE4B00']
# FOLDER Pre-v3/10400100405FEB00
# 120202003312.tif
# 120202003313.tif
# FOLDER Pre-v3/10400100797DAC00
# 120202003312.tif
# FOLDER Pre-v3/1040010045AE4B00
# 120202003312.tif
# 120202003313.tif
# Images have been renamed.

# %%
# Copy the images to the destination folder

# Iterate through the subfolders
for subfolder in subfolders:
    
    # List all files in the subfolder
    subfolder_files = os.listdir(subfolder)
    print("FOLDER",subfolder)
    
    # Iterate through the files in the subfolder
    for file in subfolder_files:
        print(file)
        
        # Get the full path to the file in the subfolder
        file_path = os.path.join(subfolder, file)
        
        # Copy the file to the main folder
        shutil.copy(file_path, dest_folder)
        
print("Images have been copied to the dest folder")
# Out:
# FOLDER Pre-v3/10400100405FEB00
# 10400100405FEB00_120202003312.tif
# 10400100405FEB00_120202003313.tif
# FOLDER Pre-v3/10400100797DAC00
# 10400100797DAC00_120202003312.tif
# FOLDER Pre-v3/1040010045AE4B00
# 1040010045AE4B00_120202003312.tif
# 1040010045AE4B00_120202003313.tif
# Images have been copied to the dest folder

# %% [markdown]
# ### Rename all post-event images and move all images into a new folder called <code>Post-event-v2</code>

# %%
#Rename post-event images

# Specify the path to your main Post-v2 folder containing subfolders with post-event images
main_folder = 'Post-v3'
dest_folder = 'Post-event-v3' 

# List all subfolders in the main folder
subfolders = [f.path for f in os.scandir(main_folder) if f.is_dir()]
print(subfolders)

# Check if the Post-event-v2 folder already exists and if not, create an empty folder
if not os.path.exists(dest_folder):
    os.mkdir(dest_folder)
    print(f"Folder '{dest_folder}' created successfully.")
else:
    print(f"Folder '{dest_folder}' already exists.")

# Iterate through the subfolders
for subfolder in subfolders:
    
    # List all files in the subfolder
    subfolder_files = os.listdir(subfolder)
    print("FOLDER",subfolder)
    
    # Iterate through the files in the subfolder
    for file in subfolder_files:
        print(file)
        
        # Get the full path to the file in the subfolder
        file_path = os.path.join(subfolder, file)

        # Create a new file name with the subfolder name as a prefix
        new_file_name = f"{os.path.basename(subfolder)}_{file}"
        
        # Get the full path to the new file in the subfolder
        new_file_path = os.path.join(subfolder, new_file_name)

        # Rename the file in the subfolder
        os.rename(file_path, new_file_path)
        
        
print("Images have been renamed.")
# Out:
# ['Post-v3/10300100ED11EA00', 'Post-v3/10300500E4F92300']
# Folder 'Post-event-v3' created successfully.
# FOLDER Post-v3/10300100ED11EA00
# 120202003312.tif
# 120202003313.tif
# FOLDER Post-v3/10300500E4F92300
# 120202003312.tif
# 120202003313.tif
# Images have been renamed.

# %%
# Copy the renamed post-event images to a new folder called 'Post-event-v2'

# Iterate through the subfolders
for subfolder in subfolders:
    
    # List all files in the subfolder
    subfolder_files = os.listdir(subfolder)
    print("FOLDER",subfolder)
    
    # Iterate through the files in the subfolder
    for file in subfolder_files:
        print(file)
        
        # Get the full path to the file in the subfolder
        file_path = os.path.join(subfolder, file)
        
        # Copy the file to the main folder
        shutil.copy(file_path, dest_folder)


print("Images have been copied to the dest folder")
# Out:
# FOLDER Post-v3/10300100ED11EA00
# 10300100ED11EA00_120202003313.tif
# 10300100ED11EA00_120202003312.tif
# FOLDER Post-v3/10300500E4F92300
# 10300500E4F92300_120202003312.tif
# 10300500E4F92300_120202003313.tif
# Images have been copied to the dest folder

# %% [markdown]
# #### Count images in the folder to check everything transferred.

# %%
# Cell reference: This work used ChatGPT-3.5 to generate the initial functions and report outline. This was done on 20/09/2023
# with the following prompts: "Generate code to count image files in a folder"

# Specify the path to your main folder containing images
main_folder = 'Post-event-v3'

# List all files in the main folder
all_files = os.listdir(main_folder)

# List of common image file extensions
image_extensions = ['.tif', '.jpeg', '.png', '.gif', '.bmp', '.tiff', '.webp']

# Initialize a counter for the number of images
image_count = 0

# Iterate through the files in the main folder
for file in all_files:
    
    # Get the file extension in lowercase
    file_extension = os.path.splitext(file)[1].lower()
    
    # Check if the file has a known image extension
    if file_extension in image_extensions:
        image_count += 1

print(f"Number of images in the main folder: {image_count}")
# Out:
# Number of images in the main folder: 4

# %% [markdown]
# #### Copy everything to the bucket

# %%
#Copy everything to my bucket
import os
import git
import subprocess
from google.cloud import storage

# Enter your own bucket name below:
mybucket = 'ml-bucket-dsmi800'
# Make a folder in your bucket called 'BDA_Data'
gs_path = f'gs://{mybucket}/BDA_Data_1/'

# Define the local directory that you want to move to the bucket
temp_directory = '.'

# Run the gsutil command to copy the data to Cloud Storage
command = f'gsutil -m cp -r {temp_directory} {gs_path}'
subprocess.run(command, shell=True)
# Out:
# Copying file://./post_vrt_tiled_v2.tif.msk [Content-Type=application/octet-stream]...
# Copying file://./BDA.ipynb [Content-Type=application/octet-stream]...
# Copying file://./post_vrt_tiled.tif [Content-Type=image/tiff]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# Copying file://./post_vrt_outline.shx [Content-Type=application/x-qgis]...
# Copying file://./post_vrt_outline_v2.dbf [Content-Type=application/vnd.dbf]...
# Copying file://./post_vrt.vrt [Content-Type=application/octet-stream]...
# Copying file://./pre_vrt_tiled.tif [Content-Type=image/tiff]...
# Copying file://./pre_vrt.vrt [Content-Type=application/octet-stream]...
# Copying file://./post_vrt_tiled_v2.tif [Content-Type=image/tiff]...
# Copying file://./pre_vrt_tiled_v2.tif [Content-Type=image/tiff]...
# Copying file://./post_vrt_tiled.tif.msk [Content-Type=application/octet-stream]...
# Copying file://./MosaicAndClip.ipynb [Content-Type=application/octet-stream]...
# Copying file://./DataDirectorySetUp.ipynb [Content-Type=application/octet-stream]...
# Copying file://./post_vrt_v2.vrt [Content-Type=application/octet-stream]...
# Copying file://./post_vrt_outline.dbf [Content-Type=application/vnd.dbf]...
# Copying file://./post_vrt_outline_v2.shp [Content-Type=application/x-qgis]...
# Copying file://./pre_vrt_v2.vrt [Content-Type=application/octet-stream]...
# Copying file://./post_vrt_outline_v2.prj [Content-Type=application/octet-stream]...
# Copying file://./post_vrt_outline.shp [Content-Type=application/x-qgis]...
# Copying file://./pre_vrt_clipped_v2.vrt [Content-Type=application/octet-stream]...
# Copying file://./DownloadMorrocoData.ipynb [Content-Type=application/octet-stream]...
# Copying file://./pre_vrt_clipped.vrt [Content-Type=application/octet-stream]...
# Copying file://./post_vrt_outline.prj [Content-Type=application/octet-stream]...
# Copying file://./BDA_tiled.ipynb [Content-Type=application/octet-stream]...
# Copying file://./post_vrt_outline_v2.shx [Content-Type=application/x-qgis]...
# Copying file://./Post-event/031313311113.tif [Content-Type=image/tiff]...
# Copying file://./Post-event/031313133313.tif [Content-Type=image/tiff]...
# Copying file://./Post-event/031313133311.tif [Content-Type=image/tiff]...
# Copying file://./Post-event/031313133131.tif [Content-Type=image/tiff]...
# Copying file://./Post-event/031313133331.tif [Content-Type=image/tiff]...
# Copying file://./Post-event/.ipynb_checkpoints/031313133131-checkpoint.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/44422c98_031313133331.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313133312.tif [Content-Type=image/tiff]...
# Copying file://./Post-event/031313133333.tif [Content-Type=image/tiff]...
# Copying file://./Post-event/031313133133.tif [Content-Type=image/tiff]...
# Copying file://./Post-event/031313311111.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313133310.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/44422c98_031313133330.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007FD1DF00_031313133330.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313133303.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313311112.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313133313.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313311103.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001003FAD9700_031313131313.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/44422c98_031313311112.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/44422c98_031313133310.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313131303.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/44422c98_031313133132.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313133111.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313131312.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010056418C00_031313133133.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313133330.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313311111.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313133121.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313311101.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313133103.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010049533A00_031313133131.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313133110.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007FD1DF00_031313133311.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313131323.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10300100D5947C00_10300100D5947C00_031313133330.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/44422c98_031313133312.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10300100D5947C00_031313133132.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007F3A4600_031313311110.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313133323.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313133313.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10300100D5947C00_031313133312.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001003FAD9700_031313133331.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007F3A4600_031313311111.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007F3A4600_031313133312.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313133333.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010062936C00_031313133133.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010056418C00_031313133330.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010056418C00_031313133333.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313131321.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313133123.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313133321.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001003FAD9700_031313133313.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007F3A4600_031313133330.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313133312.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313133133.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313311112.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/44422c98_031313311110.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10300100D5947C00_031313133321.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001003FAD9700_031313133311.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10300100D5947C00_031313133332.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313311110.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313131313.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010056418C00_031313311111.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313133301.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007FD1DF00_031313133312.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007FD1DF00_031313133332.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010062936C00_031313133313.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007F3A4600_031313133332.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313311113.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001003FAD9700_031313131333.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010056418C00_031313133311.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007F3A4600_031313311113.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001003FAD9700_031313131331.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001003FAD9700_031313133333.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313133123.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010062936C00_031313133331.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313133311.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010056418C00_031313133310.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313133312.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313133131.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313133301.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313133310.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001003FAD9700_031313133111.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313311111.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001003FAD9700_031313311111.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10300100D5947C00_031313311101.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313311112.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313133132.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10300100D5947C00_031313133301.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007FD1DF00_031313311110.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010062936C00_031313133333.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007FD1DF00_031313133313.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313133321.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/44422c98_031313311113.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313133323.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313131330.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/44422c98_031313133313.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007FD1DF00_031313311113.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007F3A4600_031313133311.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313133132.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007F3A4600_031313311101.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001003FAD9700_031313133113.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313133330.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007FD1DF00_031313311111.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313133330.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007F3A4600_031313133301.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10300100D5947C00_031313133103.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010049533A00_031313133331.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313311110.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313133333.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007F3A4600_031313133303.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313133303.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313131332.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010049533A00_031313133313.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10300100D5947C00_031313133310.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313133303.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313133301.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10300100D5947C00_031313133112.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010056418C00_031313133132.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007FD1DF00_031313311112.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010056418C00_031313311110.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001003FAD9700_031313133133.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313133331.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007F3A4600_031313133313.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/44422c98_031313133333.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313133113.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313133133.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313133130.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/44422c98_031313133332.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007F3A4600_031313133310.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313311101.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313131330.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/44422c98_031313133311.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10300100D5947C00_031313133323.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010056418C00_031313133313.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313131332.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010049533A00_031313133333.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313133332.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313133323.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007F3A4600_031313133331.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313133333.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313133133.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313133110.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313133312.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007FD1DF00_031313133310.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313133310.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010062936C00_031313133311.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007F3A4600_031313133321.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313311112.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313311103.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313133321.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313133130.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007FD1DF00_031313133331.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313131333.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10300100D5947C00_031313133130.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313133331.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010056418C00_031313133331.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10300100D5947C00_031313133121.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313131331.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010049533A00_031313133311.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313133112.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313311113.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313133132.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313133112.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010056418C00_031313133312.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313133310.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10300100D5947C00_031313133303.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007F3A4600_031313133323.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007F3A4600_031313311112.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313131312.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007FD1DF00_031313133333.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001003FAD9700_031313133131.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313133101.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313133330.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313311113.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313133132.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313133123.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007F3A4600_031313133333.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313133332.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313133311.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/04eddade_031313133313.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/44422c98_031313311111.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313311110.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313311111.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313133331.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010049533A00_031313133133.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313311101.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313311103.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/d0235025_031313133332.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313133311.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10300100D5947C00_031313311110.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010040D30400_031313133332.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010062936C00_031313311111.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001007F3A4600_031313311103.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/1040010056418C00_031313133332.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/104001003FAD9700_031313311113.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10400100406FA800_031313311110.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event/10300100D5947C00_031313133123.tif [Content-Type=image/tiff]...
# Copying file://./.ipynb_checkpoints/BDA_tiled-checkpoint.ipynb [Content-Type=application/octet-stream]...
# Copying file://./.ipynb_checkpoints/DownloadMorrocoData-checkpoint.ipynb [Content-Type=application/octet-stream]...
# Copying file://./.ipynb_checkpoints/BDA-checkpoint.ipynb [Content-Type=application/octet-stream]...
# Copying file://./.ipynb_checkpoints/DataDirectorySetUp-checkpoint.ipynb [Content-Type=application/octet-stream]...
# Copying file://./.ipynb_checkpoints/MosaicAndClip-checkpoint.ipynb [Content-Type=application/octet-stream]...
# Copying file://./Post-event-v2/10300500E4F92300_120202012022.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/104001008A8E9800_120202003123.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/104001008A8E9800_120202003302.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003321.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003310.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202012200.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F91700_120202012023.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202012221.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003313.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202012200.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202003133.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F91700_120202012201.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003122.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202012221.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003301.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202003311.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003123.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003132.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/104001008A8E9800_120202003122.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202012203.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202003321.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202012201.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202003301.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202012220.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202003312.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003130.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003311.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202003132.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003312.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202012023.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202003131.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202003130.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202003330.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003300.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202003313.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202003303.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202012020.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003121.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003330.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202012021.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202003123.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202012201.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202012021.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003302.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202012202.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202003331.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/104001008A8E9800_120202003300.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202012203.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202012202.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003331.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202012220.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202003310.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/104001008A8E9800_120202003121.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/104001008A8E9800_120202003301.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/104001008A8E9800_120202003120.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003120.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202012023.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003131.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F91700_120202012203.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202012020.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F92300_120202003121.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300500E4F91700_120202012202.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202012022.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003133.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003320.tif [Content-Type=image/tiff]...
# Copying file://./Post-event-v2/10300100ED11EA00_120202003303.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003321.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003310.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202012200.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202012221.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003313.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003122.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003301.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003123.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003132.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202012201.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003130.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003311.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003312.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202012023.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003300.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202012020.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003121.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003330.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202012021.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003302.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202012202.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202012203.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003331.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202012220.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003120.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003131.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202012022.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003133.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003320.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300100ED11EA00/10300100ED11EA00_120202003303.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/104001008A8E9800/104001008A8E9800_120202003123.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/104001008A8E9800/104001008A8E9800_120202003302.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/104001008A8E9800/104001008A8E9800_120202003122.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/104001008A8E9800/104001008A8E9800_120202003300.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/104001008A8E9800/104001008A8E9800_120202003121.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/104001008A8E9800/104001008A8E9800_120202003301.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/104001008A8E9800/104001008A8E9800_120202003120.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F91700/10300500E4F91700_120202012023.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F91700/10300500E4F91700_120202012201.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F91700/10300500E4F91700_120202012203.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F91700/10300500E4F91700_120202012202.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202012022.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202012200.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202003133.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202012221.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202003311.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202012203.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202003321.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202003301.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202012220.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202003312.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202003132.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202003131.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202003130.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202003330.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202003313.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202003303.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202003123.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202012201.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202012021.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202003331.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202012202.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202003310.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202012023.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202012020.tif [Content-Type=image/tiff]...
# Copying file://./Post-v2/10300500E4F92300/10300500E4F92300_120202003121.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10300100D5947C00/10300100D5947C00_10300100D5947C00_031313133323.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10300100D5947C00/10300100D5947C00_10300100D5947C00_031313133310.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10300100D5947C00/10300100D5947C00_10300100D5947C00_031313133312.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10300100D5947C00/10300100D5947C00_10300100D5947C00_031313311101.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10300100D5947C00/10300100D5947C00_10300100D5947C00_031313133103.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10300100D5947C00/10300100D5947C00_10300100D5947C00_031313133130.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10300100D5947C00/10300100D5947C00_10300100D5947C00_031313133132.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10300100D5947C00/10300100D5947C00_10300100D5947C00_031313133121.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10300100D5947C00/10300100D5947C00_10300100D5947C00_031313133303.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10300100D5947C00/10300100D5947C00_10300100D5947C00_10300100D5947C00_031313133330.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10300100D5947C00/10300100D5947C00_10300100D5947C00_031313133321.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10300100D5947C00/10300100D5947C00_10300100D5947C00_031313133332.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10300100D5947C00/10300100D5947C00_10300100D5947C00_031313133112.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10300100D5947C00/10300100D5947C00_10300100D5947C00_031313133301.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10300100D5947C00/10300100D5947C00_10300100D5947C00_031313133123.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10300100D5947C00/10300100D5947C00_10300100D5947C00_031313311110.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313131312.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313311103.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313133132.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313131332.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313131323.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313133303.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313311112.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313133112.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313133121.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313131303.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313131321.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313133330.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313133332.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313133110.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313133123.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313131330.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313311101.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313133130.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313133101.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313311110.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313133312.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313133321.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313133323.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313133310.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313133301.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010040D30400/1040010040D30400_1040010040D30400_031313133103.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010056418C00/1040010056418C00_1040010056418C00_031313311110.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010056418C00/1040010056418C00_1040010056418C00_031313133330.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010056418C00/1040010056418C00_1040010056418C00_031313133133.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010056418C00/1040010056418C00_1040010056418C00_031313133310.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010056418C00/1040010056418C00_1040010056418C00_031313133313.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010056418C00/1040010056418C00_1040010056418C00_031313133132.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010056418C00/1040010056418C00_1040010056418C00_031313133312.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010056418C00/1040010056418C00_1040010056418C00_031313133332.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010056418C00/1040010056418C00_1040010056418C00_031313133331.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010056418C00/1040010056418C00_1040010056418C00_031313311111.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010056418C00/1040010056418C00_1040010056418C00_031313133333.tif [Content-Type=image/tiff]...
# Copying file://./Pre/1040010056418C00/1040010056418C00_1040010056418C00_031313133311.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001007FD1DF00/104001007FD1DF00_104001007FD1DF00_031313133312.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001007FD1DF00/104001007FD1DF00_104001007FD1DF00_031313133331.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001007FD1DF00/104001007FD1DF00_104001007FD1DF00_031313311112.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001007FD1DF00/104001007FD1DF00_104001007FD1DF00_031313311110.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001007FD1DF00/104001007FD1DF00_104001007FD1DF00_031313133333.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001007FD1DF00/104001007FD1DF00_104001007FD1DF00_031313133330.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001007FD1DF00/104001007FD1DF00_104001007FD1DF00_031313311113.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001007FD1DF00/104001007FD1DF00_104001007FD1DF00_031313311111.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001007FD1DF00/104001007FD1DF00_104001007FD1DF00_031313133313.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001007FD1DF00/104001007FD1DF00_104001007FD1DF00_031313133311.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001007FD1DF00/104001007FD1DF00_104001007FD1DF00_031313133310.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001007FD1DF00/104001007FD1DF00_104001007FD1DF00_031313133332.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313311111.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313133310.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313131332.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313133130.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313133110.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313133312.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313133112.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313133111.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313131330.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313311112.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313133131.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313133332.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313133113.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313131331.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313311110.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313133333.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313133313.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313133331.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313133330.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313131313.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313133132.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313133311.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313133133.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313131333.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313311113.tif [Content-Type=image/tiff]...
# Copying file://./Pre/10400100406FA800/10400100406FA800_10400100406FA800_031313131312.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001003FAD9700/104001003FAD9700_104001003FAD9700_031313133313.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001003FAD9700/104001003FAD9700_104001003FAD9700_031313133111.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001003FAD9700/104001003FAD9700_104001003FAD9700_031313133113.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001003FAD9700/104001003FAD9700_104001003FAD9700_031313131331.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001003FAD9700/104001003FAD9700_104001003FAD9700_031313311111.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001003FAD9700/104001003FAD9700_104001003FAD9700_031313133331.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001003FAD9700/104001003FAD9700_104001003FAD9700_031313133333.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001003FAD9700/104001003FAD9700_104001003FAD9700_031313131333.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001003FAD9700/104001003FAD9700_104001003FAD9700_031313133131.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001003FAD9700/104001003FAD9700_104001003FAD9700_031313133133.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001003FAD9700/104001003FAD9700_104001003FAD9700_031313131313.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001003FAD9700/104001003FAD9700_104001003FAD9700_031313133311.tif [Content-Type=image/tiff]...
# Copying file://./Pre/104001003FAD9700/104001003FAD9700_104001003FAD9700_031313311113.tif [Content-Type=image/tiff]...
# Copying file://./Pre/d0235025/d0235025_d0235025_031313311113.tif [Content-Type=image/tiff]...
# Copying file://./Pre/d0235025/d0235025_d0235025_031313133330.tif [Content-Type=image/tiff]...
# Copying file://./Pre/d0235025/d0235025_d0235025_031313133310.tif [Content-Type=image/tiff]...
# Copying file://./Pre/d0235025/d0235025_d0235025_031313133301.tif [Content-Type=image/tiff]...
# Copying file://./Pre/d0235025/d0235025_d0235025_031313133333.tif [Content-Type=image/tiff]...
# Copying file://./Pre/d0235025/d0235025_d0235025_031313133123.tif [Content-Type=image/tiff]...
# Copying file://./Pre/d0235025/d0235025_d0235025_031313133313.tif [Content-Type=image/tiff]...
# Copying file://./Pre/d0235025/d0235025_d0235025_031313133312.tif [Content-Type=image/tiff]...
# Copying file://./Pre/d0235025/d0235025_d0235025_031313133133.tif [Content-Type=image/tiff]...
# Copying file://./Pre/d0235025/d0235025_d0235025_031313311103.tif [Content-Type=image/tiff]...
# Copying file://./Pre/d0235025/d0235025_d0235025_031313133303.tif [Content-Type=image/tiff]...
# Copying file://./Pre/d0235025/d0235025_d0235025_031313133332.tif [Content-Type=image/tiff]...
# Copying file://./Pre/d0235025/d0235025_d0235025_031313311101.tif [Content-Type=image/tiff]...
# Copying file://./Pre/d0235025/d0235025_d0235025_031313133321.tif [Content-Type=image/tiff]...
# Copying file://./Pre/d0235025/d0235025_d0235025_031313133331.tif [Content-Type=image/tiff]...
# Copying file://./Pre/d0235025/d0235025_d0235025_031313311111.tif [Content-Type=image/tiff]...
# Copying file://./Pre/d0235025/d0235025_d0235025_031313311112.tif [Content-Type=image/tiff]...
# Copying file://./Pre/d0235025/d0235025_d0235025_031313133323.tif [Content-Type=image/tiff]...
# ...
# Copying file://./Pre-event-v2/1040010083289000_120202003121.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/103001008244DA00_120202012220.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10300100CBAF7D00_120202003330.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/1040010083289000_120202003300.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10300100CBAF7D00_120202003122.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10400100797DAC00_120202003120.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/1040010045AE4B00_120202003300.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/103001008244DA00_120202003133.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/1040010083289000_120202003122.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10300100CBAF7D00_120202003132.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/1040010045AE4B00_120202003120.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/1040010083289000_120202003312.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10400100797DAC00_120202003123.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/1040010083289000_120202003132.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10400100405FEB00_120202003131.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/1040010045AE4B00_120202003330.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10400100797DAC00_120202003301.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10300100CBAF7D00_120202003310.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/103001008244DA00_120202012022.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10400100405FEB00_120202003123.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/1040010045AE4B00_120202003331.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10300100CBAF7D00_120202003303.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10300100CBAF7D00_120202003130.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/103001008244DA00_120202012202.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10400100797DAC00_120202003122.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10400100797DAC00_120202003303.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/1040050039DC5C00_120202012022.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/1040050039DC5C00_120202003131.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10400100797DAC00_120202003321.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10300100CBAF7D00_120202003320.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10400100405FEB00_120202012020.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10400100797DAC00_120202003132.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/1040010083289000_120202003310.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10300100CBAF7D00_120202003300.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10300100CBAF7D00_120202003312.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/1030010083A10700_120202003120.tif [Content-Type=image/tiff]...
# Copying file://./Pre-event-v2/10400100405FEB00_120202003130.tif [Content-Type=image/tiff]...
# Copying file://./Post-Event-BDA/Post-Event-BDA.cpg [Content-Type=application/octet-stream]...
# Copying file://./Post-Event-BDA/Post-Event-BDA.dbf [Content-Type=application/vnd.dbf]...
# Copying file://./Post-Event-BDA/Post-Event-BDA.shx [Content-Type=application/x-qgis]...
# Copying file://./Post-Event-BDA/Post-Event-BDA.shp [Content-Type=application/x-qgis]...
# Copying file://./Pre-v2/1040010083289000/1040010083289000_120202003330.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010083289000/1040010083289000_120202003301.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010083289000/1040010083289000_120202003120.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010083289000/1040010083289000_120202003123.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010083289000/1040010083289000_120202003303.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010083289000/1040010083289000_120202003130.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010083289000/1040010083289000_120202003321.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010083289000/1040010083289000_120202003320.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010083289000/1040010083289000_120202003302.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010083289000/1040010083289000_120202003121.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010083289000/1040010083289000_120202003300.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010083289000/1040010083289000_120202003122.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010083289000/1040010083289000_120202003312.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010083289000/1040010083289000_120202003132.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010083289000/1040010083289000_120202003310.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10300100CBAF7D00/10300100CBAF7D00_120202003123.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10300100CBAF7D00/10300100CBAF7D00_120202003321.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10300100CBAF7D00/10300100CBAF7D00_120202003302.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10300100CBAF7D00/10300100CBAF7D00_120202003301.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10300100CBAF7D00/10300100CBAF7D00_120202003121.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10300100CBAF7D00/10300100CBAF7D00_120202003120.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10300100CBAF7D00/10300100CBAF7D00_120202003330.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10300100CBAF7D00/10300100CBAF7D00_120202003122.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10300100CBAF7D00/10300100CBAF7D00_120202003132.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10300100CBAF7D00/10300100CBAF7D00_120202003310.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10300100CBAF7D00/10300100CBAF7D00_120202003303.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10300100CBAF7D00/10300100CBAF7D00_120202003320.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10300100CBAF7D00/10300100CBAF7D00_120202003130.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10300100CBAF7D00/10300100CBAF7D00_120202003300.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10300100CBAF7D00/10300100CBAF7D00_120202003312.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1030010083A10700/1030010083A10700_120202003300.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1030010083A10700/1030010083A10700_120202003122.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1030010083A10700/1030010083A10700_120202003320.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1030010083A10700/1030010083A10700_120202003302.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1030010083A10700/1030010083A10700_120202003120.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202003310.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202012200.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202003330.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202003312.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202003313.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202003121.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202003132.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202012220.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202003331.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202003301.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202012202.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202012022.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202003133.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202003303.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202003321.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202003311.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202003131.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202003123.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202012020.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100405FEB00/10400100405FEB00_120202003130.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/103001008244DA00/103001008244DA00_120202003311.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/103001008244DA00/103001008244DA00_120202012201.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/103001008244DA00/103001008244DA00_120202012023.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/103001008244DA00/103001008244DA00_120202012200.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/103001008244DA00/103001008244DA00_120202012021.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/103001008244DA00/103001008244DA00_120202012221.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/103001008244DA00/103001008244DA00_120202012020.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/103001008244DA00/103001008244DA00_120202003131.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/103001008244DA00/103001008244DA00_120202012203.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/103001008244DA00/103001008244DA00_120202003331.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/103001008244DA00/103001008244DA00_120202003313.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/103001008244DA00/103001008244DA00_120202012220.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/103001008244DA00/103001008244DA00_120202003133.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/103001008244DA00/103001008244DA00_120202012022.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/103001008244DA00/103001008244DA00_120202012202.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040050039DC5C00/1040050039DC5C00_120202012023.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040050039DC5C00/1040050039DC5C00_120202003133.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040050039DC5C00/1040050039DC5C00_120202012020.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040050039DC5C00/1040050039DC5C00_120202012021.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040050039DC5C00/1040050039DC5C00_120202012022.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040050039DC5C00/1040050039DC5C00_120202003131.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100797DAC00/10400100797DAC00_120202003130.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100797DAC00/10400100797DAC00_120202003310.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100797DAC00/10400100797DAC00_120202003320.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100797DAC00/10400100797DAC00_120202003300.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100797DAC00/10400100797DAC00_120202003330.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100797DAC00/10400100797DAC00_120202003312.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100797DAC00/10400100797DAC00_120202003302.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100797DAC00/10400100797DAC00_120202003121.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100797DAC00/10400100797DAC00_120202003120.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100797DAC00/10400100797DAC00_120202003123.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100797DAC00/10400100797DAC00_120202003301.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100797DAC00/10400100797DAC00_120202003122.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100797DAC00/10400100797DAC00_120202003303.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100797DAC00/10400100797DAC00_120202003321.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/10400100797DAC00/10400100797DAC00_120202003132.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003131.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003310.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003123.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003122.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003121.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003302.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003303.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003311.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003321.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003312.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003313.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003133.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003301.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003320.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003132.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003130.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003300.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003120.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003330.tif [Content-Type=image/tiff]...
# Copying file://./Pre-v2/1040010045AE4B00/1040010045AE4B00_120202003331.tif [Content-Type=image/tiff]...
# Copying file://./Pre-Event-BDA/Pre-Event-BDA.shx [Content-Type=application/x-qgis]...
# Copying file://./Pre-Event-BDA/Pre-Event-BDA.cpg [Content-Type=application/octet-stream]...
# Copying file://./Pre-Event-BDA/Pre-Event-BDA.dbf [Content-Type=application/vnd.dbf]...
# Copying file://./Pre-Event-BDA/Pre-Event-BDA.shp [Content-Type=application/x-qgis]...
# | [781/781 files][ 94.4 GiB/ 94.4 GiB] 100% Done  96.3 MiB/s ETA 00:00:00
# Operation completed over 781 objects/94.4 GiB.
# CompletedProcess(args='gsutil -m cp -r . gs://ml-bucket-dsmi800/BDA_Data_1/', returncode=0)

# %% [markdown]
# Now move on to the <code>MosaicAndClip.ipynb</code> file
