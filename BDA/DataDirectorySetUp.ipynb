# %%
#PRE_EVENT IMAGES RENAME
import os
import shutil

# Specify the path to your main folder containing subfolders with images
main_folder = 'Pre-v2' # all subfolders moved to a folder named pre
dest_folder = 'Pre-event-v2' #create an empty folder named pre-event

# List all subfolders in the main folder
subfolders = [f.path for f in os.scandir(main_folder) if f.is_dir()]
print(subfolders)
# Iterate through the subfolders
for subfolder in subfolders:
    # List all files in the subfolder
    subfolder_files = os.listdir(subfolder)
    print("FOLDER",subfolder)
    # Iterate through the files in the subfolder
    
    for file in subfolder_files:
        print(file)
        # Get the full path to the file in the subfolder
        file_path = os.path.join(subfolder, file)

        # Create a new file name with the subfolder name as a prefix
        new_file_name = f"{os.path.basename(subfolder)}_{file}"
        
        # Get the full path to the new file in the subfolder
        new_file_path = os.path.join(subfolder, new_file_name)

        # Rename the file in the subfolder
        os.rename(file_path, new_file_path)
        
        
print("Images have been renamed.")
# Out:
# ['Pre-v2/1040010083289000', 'Pre-v2/10300100CBAF7D00', 'Pre-v2/1030010083A10700', 'Pre-v2/10400100405FEB00', 'Pre-v2/103001008244DA00', 'Pre-v2/1040050039DC5C00', 'Pre-v2/10400100797DAC00', 'Pre-v2/1040010045AE4B00']
# FOLDER Pre-v2/1040010083289000
# 120202003320.tif
# 120202003312.tif
# 120202003122.tif
# 120202003330.tif
# 120202003123.tif
# 120202003130.tif
# 120202003132.tif
# 120202003303.tif
# 120202003121.tif
# 120202003321.tif
# 120202003302.tif
# 120202003310.tif
# 120202003301.tif
# 120202003300.tif
# 120202003120.tif
# FOLDER Pre-v2/10300100CBAF7D00
# 120202003320.tif
# 120202003312.tif
# 120202003122.tif
# 120202003330.tif
# 120202003123.tif
# 120202003130.tif
# 120202003132.tif
# 120202003303.tif
# 120202003121.tif
# 120202003321.tif
# 120202003302.tif
# 120202003310.tif
# 120202003301.tif
# 120202003300.tif
# 120202003120.tif
# FOLDER Pre-v2/1030010083A10700
# 120202003320.tif
# 120202003122.tif
# 120202003302.tif
# 120202003300.tif
# 120202003120.tif
# FOLDER Pre-v2/10400100405FEB00
# 120202012200.tif
# 120202003312.tif
# 120202003330.tif
# 120202003123.tif
# 120202003130.tif
# 120202012220.tif
# 120202003313.tif
# 120202003132.tif
# 120202012202.tif
# 120202003303.tif
# 120202003121.tif
# 120202003321.tif
# 120202012022.tif
# 120202003310.tif
# 120202003301.tif
# 120202012020.tif
# 120202003311.tif
# 120202003133.tif
# 120202003131.tif
# 120202003331.tif
# FOLDER Pre-v2/103001008244DA00
# 120202012200.tif
# 120202012023.tif
# 120202012220.tif
# 120202012221.tif
# 120202003313.tif
# 120202012202.tif
# 120202012021.tif
# 120202012203.tif
# 120202012022.tif
# 120202012020.tif
# 120202003311.tif
# 120202003133.tif
# 120202003131.tif
# 120202012201.tif
# 120202003331.tif
# FOLDER Pre-v2/1040050039DC5C00
# 120202012023.tif
# 120202012021.tif
# 120202012022.tif
# 120202012020.tif
# 120202003133.tif
# 120202003131.tif
# FOLDER Pre-v2/10400100797DAC00
# 120202003320.tif
# 120202003312.tif
# 120202003122.tif
# 120202003330.tif
# 120202003123.tif
# 120202003130.tif
# 120202003132.tif
# 120202003303.tif
# 120202003121.tif
# 120202003321.tif
# 120202003302.tif
# 120202003310.tif
# 120202003301.tif
# 120202003300.tif
# 120202003120.tif
# FOLDER Pre-v2/1040010045AE4B00
# 120202003320.tif
# 120202003312.tif
# 120202003122.tif
# 120202003330.tif
# 120202003123.tif
# 120202003130.tif
# 120202003313.tif
# 120202003132.tif
# 120202003303.tif
# 120202003121.tif
# 120202003321.tif
# 120202003302.tif
# 120202003310.tif
# 120202003301.tif
# 120202003300.tif
# 120202003120.tif
# 120202003311.tif
# 120202003133.tif
# 120202003131.tif
# 120202003331.tif
# Images have been renamed.

# %%
import os
import shutil

# Specify the path to your main folder containing subfolders with images
main_folder = 'Pre-v2' # all subfolders moved to a folder named pre


dest_folder = 'Pre-event-v2' #create an empty folder named pre-event
# Check if the folder already exists
if not os.path.exists(dest_folder):
    os.mkdir(dest_folder)
    print(f"Folder '{dest_folder}' created successfully.")
else:
    print(f"Folder '{dest_folder}' already exists.")

# List all subfolders in the main folder
subfolders = [f.path for f in os.scandir(main_folder) if f.is_dir()]
print(subfolders)
# Iterate through the subfolders
for subfolder in subfolders:
    # List all files in the subfolder
    subfolder_files = os.listdir(subfolder)
    print("FOLDER",subfolder)
    # Iterate through the files in the subfolder
    
    for file in subfolder_files:
        print(file)
        # Get the full path to the file in the subfolder
        file_path = os.path.join(subfolder, file)
        
        # Copy the file to the main folder
        shutil.copy(file_path, dest_folder)
        
        # Delete the file in the subfolder
        #os.remove(file_path)

print("Images have been copied to the dest folder")
# Out:
# Folder 'Pre-event-v2' created successfully.
# ['Pre-v2/1040010083289000', 'Pre-v2/10300100CBAF7D00', 'Pre-v2/1030010083A10700', 'Pre-v2/10400100405FEB00', 'Pre-v2/103001008244DA00', 'Pre-v2/1040050039DC5C00', 'Pre-v2/10400100797DAC00', 'Pre-v2/1040010045AE4B00']
# FOLDER Pre-v2/1040010083289000
# 1040010083289000_120202003330.tif
# 1040010083289000_120202003301.tif
# 1040010083289000_120202003120.tif
# 1040010083289000_120202003123.tif
# 1040010083289000_120202003303.tif
# 1040010083289000_120202003130.tif
# 1040010083289000_120202003321.tif
# 1040010083289000_120202003320.tif
# 1040010083289000_120202003302.tif
# 1040010083289000_120202003121.tif
# 1040010083289000_120202003300.tif
# 1040010083289000_120202003122.tif
# 1040010083289000_120202003312.tif
# 1040010083289000_120202003132.tif
# 1040010083289000_120202003310.tif
# FOLDER Pre-v2/10300100CBAF7D00
# 10300100CBAF7D00_120202003123.tif
# 10300100CBAF7D00_120202003321.tif
# 10300100CBAF7D00_120202003302.tif
# 10300100CBAF7D00_120202003301.tif
# 10300100CBAF7D00_120202003121.tif
# 10300100CBAF7D00_120202003120.tif
# 10300100CBAF7D00_120202003330.tif
# 10300100CBAF7D00_120202003122.tif
# 10300100CBAF7D00_120202003132.tif
# 10300100CBAF7D00_120202003310.tif
# 10300100CBAF7D00_120202003303.tif
# 10300100CBAF7D00_120202003130.tif
# 10300100CBAF7D00_120202003320.tif
# 10300100CBAF7D00_120202003300.tif
# 10300100CBAF7D00_120202003312.tif
# FOLDER Pre-v2/1030010083A10700
# 1030010083A10700_120202003300.tif
# 1030010083A10700_120202003122.tif
# 1030010083A10700_120202003320.tif
# 1030010083A10700_120202003302.tif
# 1030010083A10700_120202003120.tif
# FOLDER Pre-v2/10400100405FEB00
# 10400100405FEB00_120202003310.tif
# 10400100405FEB00_120202012200.tif
# 10400100405FEB00_120202003330.tif
# 10400100405FEB00_120202003312.tif
# 10400100405FEB00_120202003313.tif
# 10400100405FEB00_120202003121.tif
# 10400100405FEB00_120202003132.tif
# 10400100405FEB00_120202012220.tif
# 10400100405FEB00_120202003331.tif
# 10400100405FEB00_120202003301.tif
# 10400100405FEB00_120202012202.tif
# 10400100405FEB00_120202012022.tif
# 10400100405FEB00_120202003133.tif
        # Get the full path to the file in the subfolder
        file_path = os.path.join(subfolder, file)

        # Create a new file name with the subfolder name as a prefix
        new_file_name = f"{os.path.basename(subfolder)}_{file}"
        
        # Get the full path to the new file in the subfolder
        new_file_path = os.path.join(subfolder, new_file_name)

        # Rename the file in the subfolder
        os.rename(file_path, new_file_path)
        
        
print("Images have been renamed.")
# Out:
# ['Post-v2/10300100ED11EA00', 'Post-v2/104001008A8E9800', 'Post-v2/10300500E4F91700', 'Post-v2/10300500E4F92300']
# FOLDER Post-v2/10300100ED11EA00
# 120202012200.tif
# 120202003320.tif
# 120202003312.tif
# 120202003122.tif
# 120202003330.tif
# 120202003123.tif
# 120202012023.tif
# 120202003130.tif
# 120202012220.tif
# 120202012221.tif
# 120202003313.tif
# 120202003132.tif
# 120202012202.tif
# 120202003303.tif
# 120202003121.tif
# 120202003321.tif
# 120202003302.tif
# 120202012021.tif
# 120202012203.tif
# 120202012022.tif
# 120202003310.tif
# 120202003301.tif
# 120202003300.tif
# 120202003120.tif
# 120202012020.tif
# 120202003311.tif
# 120202003133.tif
# 120202003131.tif
# 120202012201.tif
# 120202003331.tif
# FOLDER Post-v2/104001008A8E9800
# 120202003122.tif
# 120202003123.tif
# 120202003121.tif
# 120202003302.tif
# 120202003301.tif
# 120202003300.tif
# 120202003120.tif
# FOLDER Post-v2/10300500E4F91700
# 120202012023.tif
# 120202012202.tif
# 120202012203.tif
# 120202012201.tif
# FOLDER Post-v2/10300500E4F92300
# 120202012200.tif
# 120202003312.tif
# 120202003330.tif
# 120202003123.tif
# 120202012023.tif
# 120202003130.tif
# 120202012220.tif
# 120202012221.tif
# 120202003313.tif
# 120202003132.tif
# 120202012202.tif
# 120202003303.tif
# 120202003121.tif
# 120202003321.tif
# 120202012021.tif
# 120202012203.tif
# 120202012022.tif
# 120202003310.tif
# 120202003301.tif
# 120202012020.tif
# 120202003311.tif
# 120202003133.tif
# 120202003131.tif
# 120202012201.tif
# 120202003331.tif
# Images have been renamed.

# %%
# POST EVENT
import os
import shutil

# Specify the path to your main folder containing subfolders with images
main_folder = 'Post-v2' # all subfolders moved to a folder named pre
dest_folder = 'Post-event-v2' #create an empty folder named post-event

# Check if the folder already exists
if not os.path.exists(dest_folder):
    os.mkdir(dest_folder)
    print(f"Folder '{dest_folder}' created successfully.")
else:
    print(f"Folder '{dest_folder}' already exists.")


# List all subfolders in the main folder
subfolders = [f.path for f in os.scandir(main_folder) if f.is_dir()]
print(subfolders)
# Iterate through the subfolders
for subfolder in subfolders:
    # List all files in the subfolder
    subfolder_files = os.listdir(subfolder)
    print("FOLDER",subfolder)
    # Iterate through the files in the subfolder
    
    for file in subfolder_files:
        print(file)
        # Get the full path to the file in the subfolder
        file_path = os.path.join(subfolder, file)
        
        # Copy the file to the main folder
        shutil.copy(file_path, dest_folder)
        
        # Delete the file in the subfolder
        #os.remove(file_path)

print("Images have been copied to the dest folder")
# Out:
# Folder 'Post-event-v2' created successfully.
# ['Post-v2/10300100ED11EA00', 'Post-v2/104001008A8E9800', 'Post-v2/10300500E4F91700', 'Post-v2/10300500E4F92300']
# FOLDER Post-v2/10300100ED11EA00
'.jpeg', '.png', '.gif', '.bmp', '.tiff', '.webp']

# Initialize a counter for the number of images
image_count = 0

# Iterate through the files in the main folder
for file in all_files:
    
    # Get the file extension in lowercase
    file_extension = os.path.splitext(file)[1].lower()
    
    # Check if the file has a known image extension
    if file_extension in image_extensions:
        image_count += 1

print(f"Number of images in the main folder: {image_count}")
# Out:
# Number of images in the main folder: 66

# %%
#Copy everything to my bucket
import os
import git
import subprocess
from google.cloud import storage

mybucket = 'ml_bucket_dsmi800'
gs_path = f'gs://{mybucket}/BDA_Data/'

# Define the local directory that you want to move to the bucket
temp_directory = 'BDA'

# Run the gsutil command to copy the data to Cloud Storage
command = f'gsutil -m cp -r {temp_directory} {gs_path}'
subprocess.run(command, shell=True)
# Out:
# Copying file://BDA/BDA.ipynb [Content-Type=application/octet-stream]...
# Copying file://BDA/Pre-event1 [Content-Type=application/octet-stream]...
# Copying file://BDA/MosaicAndClip.ipynb [Content-Type=application/octet-stream]...
# Copying file://BDA/Untitled.ipynb [Content-Type=application/octet-stream]...
# Copying file://BDA/761_Lab6_cloudGEEtensorflow.ipynb [Content-Type=application/octet-stream]...
# Copying file://BDA/DownloadMorrocoData.ipynb [Content-Type=application/octet-stream]...
# Copying file://BDA/Post-event/031313311113.tif [Content-Type=image/tiff]...
# Copying file://BDA/Post-event/031313133313.tif [Content-Type=image/tiff]...
# Copying file://BDA/Post-event/031313133311.tif [Content-Type=image/tiff]...
# Copying file://BDA/Post-event/031313133131.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/10400100406FA800_031313133313.tif [Content-Type=image/tiff]...
# Copying file://BDA/Post-event/031313311111.tif [Content-Type=image/tiff]...
# Copying file://BDA/Post-event/031313133333.tif [Content-Type=image/tiff]...
# Copying file://BDA/Post-event/031313133331.tif [Content-Type=image/tiff]...
# Copying file://BDA/Post-event/031313133133.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/04eddade_031313133312.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001003FAD9700_031313131313.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/10400100406FA800_031313133111.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/04eddade_031313311103.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010040D30400_031313133330.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010040D30400_031313133303.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/44422c98_031313311112.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001007FD1DF00_031313133330.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/44422c98_031313133310.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/44422c98_031313133132.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010040D30400_031313131303.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010056418C00_031313133133.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/04eddade_031313311111.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/10400100406FA800_031313131312.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/44422c98_031313133331.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010040D30400_031313131321.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010049533A00_031313133131.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001007FD1DF00_031313133311.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010040D30400_031313133110.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010040D30400_031313131323.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010040D30400_031313133103.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/10300100D5947C00_10300100D5947C00_031313133330.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/44422c98_031313133312.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/10300100D5947C00_031313133132.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001007F3A4600_031313311111.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/04eddade_031313311112.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010040D30400_031313133121.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001007F3A4600_031313133312.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010040D30400_031313133323.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/d0235025_031313133313.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001003FAD9700_031313133331.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001007F3A4600_031313311110.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/10300100D5947C00_031313133312.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010040D30400_031313311101.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010056418C00_031313311111.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/d0235025_031313133333.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010062936C00_031313133133.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/10400100406FA800_031313133310.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010056418C00_031313133333.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/04eddade_031313133123.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/d0235025_031313311112.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/d0235025_031313133312.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/44422c98_031313311110.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/10300100D5947C00_031313133321.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010056418C00_031313133330.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001003FAD9700_031313133313.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010040D30400_031313133321.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001007F3A4600_031313133330.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/44422c98_031313133330.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001003FAD9700_031313133311.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/d0235025_031313133133.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010040D30400_031313133301.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/10300100D5947C00_031313133332.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/10400100406FA800_031313131313.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010062936C00_031313133313.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001007FD1DF00_031313133332.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001007FD1DF00_031313133312.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/10400100406FA800_031313311113.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001007F3A4600_031313133332.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010056418C00_031313133311.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001007F3A4600_031313311113.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001003FAD9700_031313133333.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001003FAD9700_031313131331.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001003FAD9700_031313131333.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/04eddade_031313311110.tif [Content-Type=image/tiff]...
# NotFoundException: 404 The destination bucket gs://ml_bucket_dsmi800 does not exist or the write to the destination must be restarted
# Copying file://BDA/Pre-event/d0235025_031313133123.tif [Content-Type=image/tiff]...
# NotFoundException: 404 The destination bucket gs://ml_bucket_dsmi800 does not exist or the write to the destination must be restarted
# NotFoundException: 404 The destination bucket gs://ml_bucket_dsmi800 does not exist or the write to the destination must be restarted
# NotFoundException: 404 The destination bucket gs://ml_bucket_dsmi800 does not exist or the write to the destination must be restarted
# Copying file://BDA/Pre-event/1040010062936C00_031313133331.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/04eddade_031313133311.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010056418C00_031313133310.tif [Content-Type=image/tiff]...
# NotFoundException: 404 The destination bucket gs://ml_bucket_dsmi800 does not exist or the write to the destination must be restarted
# Copying file://BDA/Pre-event/10400100406FA800_031313133312.tif [Content-Type=image/tiff]...
# NotFoundException: 404 The destination bucket gs://ml_bucket_dsmi800 does not exist or the write to the destination must be restarted
# Copying file://BDA/Pre-event/10400100406FA800_031313133131.tif [Content-Type=image/tiff]...
# NotFoundException: 404 The destination bucket gs://ml_bucket_dsmi800 does not exist or the write to the destination must be restarted
# NotFoundException: 404 The destination bucket gs://ml_bucket_dsmi800 does not exist or the write to the destination must be restarted
# Copying file://BDA/Pre-event/04eddade_031313133301.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001003FAD9700_031313133111.tif [Content-Type=image/tiff]...
# NotFoundException: 404 The destination bucket gs://ml_bucket_dsmi800 does not exist or the write to the destination must be restarted
# Copying file://BDA/Pre-event/d0235025_031313133310.tif [Content-Type=image/tiff]...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/04eddade_031313311103.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# NotFoundException: 404 The destination bucket gs://ml_bucket_dsmi800 does not exist or the write to the destination must be restarted
# Copying file://BDA/Pre-event/10400100406FA800_031313311111.tif [Content-Type=image/tiff]...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/10400100406FA800_031313311113.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# NotFoundException: 404 The destination bucket gs://ml_bucket_dsmi800 does not exist or the write to the destination must be restarted
# Copying file://BDA/Pre-event/104001003FAD9700_031313311111.tif [Content-Type=image/tiff]...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/1040010040D30400_031313311101.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/1040010040D30400_031313133110.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/104001003FAD9700_031313133313.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/104001003FAD9700_031313131333.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/1040010040D30400_031313133301.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/44422c98_031313133330.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/44422c98_031313133312.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/04eddade_031313311110.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event1.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/d0235025_031313133123.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Post-event/031313133311.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/44422c98_031313133132.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/104001007FD1DF00_031313133312.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Deleted tracker file /home/jupyter/.gsutil/tracker-files/upload_TRACKER_190f9ec809fb61f956a46daa8da671d81597317b.03.tif__JSON.url for resumable upload of file://BDA/Pre-event/04eddade_031313311103.tif before retrying.
# BucketNotFoundException: 404 gs://ml_bucket_dsmi800 bucket does not exist.
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/44422c98_031313311112.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Copying file://BDA/Pre-event/10300100D5947C00_031313311101.tif [Content-Type=image/tiff]...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/104001003FAD9700_031313133311.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/1040010040D30400_031313131303.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/1040010040D30400_031313133303.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Deleted tracker file /home/jupyter/.gsutil/tracker-files/upload_TRACKER_aa3cca6417b3b924657327c03807e9cde3af15be.33.tif__JSON.url for resumable upload of file://BDA/Pre-event/104001003FAD9700_031313131333.tif before retrying.
# Deleted tracker file /home/jupyter/.gsutil/tracker-files/upload_TRACKER_be3694277fae273cd54cc488d3288387b10d638e.13.tif__JSON.url for resumable upload of file://BDA/Pre-event/10400100406FA800_031313311113.tif before retrying.
# BucketNotFoundException: 404 gs://ml_bucket_dsmi800 bucket does not exist.
# Deleted tracker file /home/jupyter/.gsutil/tracker-files/upload_TRACKER_13942b2fcd0c6c265864042167593655d4c01851.10.tif__JSON.url for resumable upload of file://BDA/Pre-event/1040010040D30400_031313133110.tif before retrying.
# BucketNotFoundException: 404 gs://ml_bucket_dsmi800 bucket does not exist.
# BucketNotFoundException: 404 gs://ml_bucket_dsmi800 bucket does not exist.
# Deleted tracker file /home/jupyter/.gsutil/tracker-files/upload_TRACKER_3df142e7d800ab581e33437d726668f050f82f44.01.tif__JSON.url for resumable upload of file://BDA/Pre-event/1040010040D30400_031313133301.tif before retrying.
# Deleted tracker file /home/jupyter/.gsutil/tracker-files/upload_TRACKER_0afe4602377cadcf8f18bece0d6b8220981ae536.01.tif__JSON.url for resumable upload of file://BDA/Pre-event/1040010040D30400_031313311101.tif before retrying.
# BucketNotFoundException: 404 gs://ml_bucket_dsmi800 bucket does not exist.
# BucketNotFoundException: 404 gs://ml_bucket_dsmi800 bucket does not exist.
# Copying file://BDA/Pre-event/10400100406FA800_031313133132.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010040D30400_031313311112.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/10300100D5947C00_031313133301.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/104001007FD1DF00_031313311110.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/1040010062936C00_031313133333.tif [Content-Type=image/tiff]...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/04eddade_031313311112.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/1040010040D30400_031313131321.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/10400100406FA800_031313131313.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/1040010040D30400_031313133103.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/104001007F3A4600_031313311113.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/104001003FAD9700_031313131331.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/d0235025_031313133333.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/d0235025_031313133313.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Deleted tracker file /home/jupyter/.gsutil/tracker-files/upload_TRACKER_3be078a6b5fb451aae4355dfc8e8d803ef15f359.10.tif__JSON.url for resumable upload of file://BDA/Pre-event/04eddade_031313311110.tif before retrying.
# BucketNotFoundException: 404 gs://ml_bucket_dsmi800 bucket does not exist.
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/10300100D5947C00_031313133132.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Deleted tracker file /home/jupyter/.gsutil/tracker-files/upload_TRACKER_33cb4952e271d2e76b24706be06fa06cd4a0dcc6.13.tif__JSON.url for resumable upload of file://BDA/Pre-event/104001003FAD9700_031313133313.tif before retrying.
# BucketNotFoundException: 404 gs://ml_bucket_dsmi800 bucket does not exist.
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/104001003FAD9700_031313131313.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Copying file://BDA/Pre-event/104001007FD1DF00_031313133313.tif [Content-Type=image/tiff]...
# Copying file://BDA/Pre-event/d0235025_031313133321.tif [Content-Type=image/tiff]...
# Caught ResumableUploadStartOverException for upload of file://BDA/Post-event/031313133333.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/104001007F3A4600_031313133330.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/10300100D5947C00_031313133332.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/104001007FD1DF00_031313133311.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Caught ResumableUploadStartOverException for upload of file://BDA/Pre-event/04eddade_031313311111.tif.
# Checking that bucket ml_bucket_dsmi800 exists before retrying upload...
# Deleted tracker file /home/jupyter/.gsutil/tracker-files/upload_TRACKER